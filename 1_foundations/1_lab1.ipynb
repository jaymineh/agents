# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-5.4-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# In the set of all 5-digit numbers (leading digit nonzero), how many contain at least one repeated digit, given that digits can repeat and that the number must be divisible by 72?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# You are given 12 identical-looking coins, exactly one of which is counterfeit and differs in weight from the others, but you do not know whether it is heavier or lighter. Using a balance scale exactly three times, determine a strategy that always identifies the counterfeit coin and whether it is heavier or lighter. What is the strategy?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Here is a standard **3-weighing strategy** for the 12-coin problem that always identifies the fake coin and tells whether it is **heavier or lighter**.
#
# Label the coins **1–12**.
#
# ---
#
# ## Weighing 1
# Weigh:
#
# - **1, 2, 3, 4**
# against
# - **5, 6, 7, 8**
#
# There are 3 possible outcomes:
#
# ### Case A: Balance
# Then the fake coin is among **9, 10, 11, 12**.
#
# ### Case B: Left side heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and is **heavier**, or
# - one of **5, 6, 7, 8** and is **lighter**.
#
# ### Case C: Right side heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and is **lighter**, or
# - one of **5, 6, 7, 8** and is **heavier**.
#
# ---
#
# # Case A: Weighing 1 balances
# So the fake is among **9, 10, 11, 12**.
#
# ## Weighing 2
# Weigh:
#
# - **9, 10, 11**
# against
# - **1, 2, 3**
# (known genuine coins)
#
# ### If balance:
# Then **12** is fake.
#
# ## Weighing 3
# Weigh **12** against **1**.
#
# - If 12 is heavier, it’s **heavy**
# - If 12 is lighter, it’s **light**
#
# ### If left side heavier:
# Then one of **9, 10, 11** is **heavy**
#
# ## Weighing 3
# Weigh **9** against **10**.
#
# - If one side is heavier, that coin is the fake and **heavy**
# - If they balance, then **11** is fake and **heavy**
#
# ### If right side heavier:
# Then one of **9, 10, 11** is **light**
#
# ## Weighing 3
# Weigh **9** against **10**.
#
# - If one side is lighter, that coin is the fake and **light**
# - If they balance, then **11** is fake and **light**
#
# ---
#
# # Case B: Weighing 1 left side heavier
# Possible fakes:
#
# - **1,2,3,4** heavy
# - **5,6,7,8** light
#
# ## Weighing 2
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# (where 9 is known genuine from Case B? Actually not yet; use any one coin from 9–12 only if available.
# So instead use a coin known genuine from the unweighed group after the first weighing, say **9** is genuine.)
#
# Let's use **9** as a genuine coin.
#
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# Now interpret:
#
# ### If left side heavier:
# Possible fake: **1 heavy, 2 heavy, 6 light**
#
# ## Weighing 3
# Weigh **1** vs **2**.
#
# - If one is heavier, that is the fake and **heavy**
# - If they balance, then **6** is fake and **light**
#
# ### If right side heavier:
# Possible fake: **3 heavy, 5 light**
#
# ## Weighing 3
# Weigh **3** vs **9**.
#
# - If 3 is heavier, then **3** is fake and **heavy**
# - If they balance, then **5** is fake and **light**
#
# ### If balance:
# Possible fake: **4 heavy, 7 light, 8 light**
#
# ## Weighing 3
# Weigh **7** vs **8**.
#
# - If one side is lighter, that coin is fake and **light**
# - If they balance, then **4** is fake and **heavy**
#
# ---
#
# # Case C: Weighing 1 right side heavier
# This is symmetric to Case B.
#
# Possible fakes:
#
# - **1,2,3,4** light
# - **5,6,7,8** heavy
#
# ## Weighing 2
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# ### If left side heavier:
# Possible fake: **3 light, 5 heavy**
#
# ## Weighing 3
# Weigh **3** vs **9**.
#
# - If 3 is lighter, then **3** is fake and **light**
# - If they balance, then **5** is fake and **heavy**
#
# ### If right side heavier:
# Possible fake: **1 light, 2 light, 6 heavy**
#
# ## Weighing 3
# Weigh **1** vs **2**.
#
# - If one is lighter, that coin is fake and **light**
# - If they balance, then **6** is fake and **heavy**
#
# ### If balance:
# Possible fake: **4 light, 7 heavy, 8 heavy**
#
# ## Weighing 3
# Weigh **7** vs **8**.
#
# - If one side is heavier, that coin is fake and **heavy**
# - If they balance, then **4** is fake and **light**
#
# ---
#
# ## Summary
# This is a complete 3-weighing decision tree that always works:
#
# 1. Weigh **1,2,3,4** vs **5,6,7,8**
# 2. Depending on outcome, use the second weighing to narrow to 2–3 candidates
# 3. Third weighing identifies the exact coin and whether it is heavy or light
#
# ---
#
# If you want, I can also give this as a **compact table** or the **classic optimal 3-weighing scheme** in a more elegant decision-tree format.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here is a standard **3-weighing strategy** for the 12-coin problem that always identifies the fake coin and tells whether it is **heavier or lighter**.
#
# Label the coins **1–12**.
#
# ---
#
# ## Weighing 1
# Weigh:
#
# - **1, 2, 3, 4**
# against
# - **5, 6, 7, 8**
#
# There are 3 possible outcomes:
#
# ### Case A: Balance
# Then the fake coin is among **9, 10, 11, 12**.
#
# ### Case B: Left side heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and is **heavier**, or
# - one of **5, 6, 7, 8** and is **lighter**.
#
# ### Case C: Right side heavier
# Then the fake coin is either:
#
# - one of **1, 2, 3, 4** and is **lighter**, or
# - one of **5, 6, 7, 8** and is **heavier**.
#
# ---
#
# # Case A: Weighing 1 balances
# So the fake is among **9, 10, 11, 12**.
#
# ## Weighing 2
# Weigh:
#
# - **9, 10, 11**
# against
# - **1, 2, 3**
# (known genuine coins)
#
# ### If balance:
# Then **12** is fake.
#
# ## Weighing 3
# Weigh **12** against **1**.
#
# - If 12 is heavier, it’s **heavy**
# - If 12 is lighter, it’s **light**
#
# ### If left side heavier:
# Then one of **9, 10, 11** is **heavy**
#
# ## Weighing 3
# Weigh **9** against **10**.
#
# - If one side is heavier, that coin is the fake and **heavy**
# - If they balance, then **11** is fake and **heavy**
#
# ### If right side heavier:
# Then one of **9, 10, 11** is **light**
#
# ## Weighing 3
# Weigh **9** against **10**.
#
# - If one side is lighter, that coin is the fake and **light**
# - If they balance, then **11** is fake and **light**
#
# ---
#
# # Case B: Weighing 1 left side heavier
# Possible fakes:
#
# - **1,2,3,4** heavy
# - **5,6,7,8** light
#
# ## Weighing 2
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# (where 9 is known genuine from Case B? Actually not yet; use any one coin from 9–12 only if available.
# So instead use a coin known genuine from the unweighed group after the first weighing, say **9** is genuine.)
#
# Let's use **9** as a genuine coin.
#
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# Now interpret:
#
# ### If left side heavier:
# Possible fake: **1 heavy, 2 heavy, 6 light**
#
# ## Weighing 3
# Weigh **1** vs **2**.
#
# - If one is heavier, that is the fake and **heavy**
# - If they balance, then **6** is fake and **light**
#
# ### If right side heavier:
# Possible fake: **3 heavy, 5 light**
#
# ## Weighing 3
# Weigh **3** vs **9**.
#
# - If 3 is heavier, then **3** is fake and **heavy**
# - If they balance, then **5** is fake and **light**
#
# ### If balance:
# Possible fake: **4 heavy, 7 light, 8 light**
#
# ## Weighing 3
# Weigh **7** vs **8**.
#
# - If one side is lighter, that coin is fake and **light**
# - If they balance, then **4** is fake and **heavy**
#
# ---
#
# # Case C: Weighing 1 right side heavier
# This is symmetric to Case B.
#
# Possible fakes:
#
# - **1,2,3,4** light
# - **5,6,7,8** heavy
#
# ## Weighing 2
# Weigh:
#
# - **1, 2, 5**
# against
# - **3, 6, 9**
#
# ### If left side heavier:
# Possible fake: **3 light, 5 heavy**
#
# ## Weighing 3
# Weigh **3** vs **9**.
#
# - If 3 is lighter, then **3** is fake and **light**
# - If they balance, then **5** is fake and **heavy**
#
# ### If right side heavier:
# Possible fake: **1 light, 2 light, 6 heavy**
#
# ## Weighing 3
# Weigh **1** vs **2**.
#
# - If one is lighter, that coin is fake and **light**
# - If they balance, then **6** is fake and **heavy**
#
# ### If balance:
# Possible fake: **4 light, 7 heavy, 8 heavy**
#
# ## Weighing 3
# Weigh **7** vs **8**.
#
# - If one side is heavier, that coin is fake and **heavy**
# - If they balance, then **4** is fake and **light**
#
# ---
#
# ## Summary
# This is a complete 3-weighing decision tree that always works:
#
# 1. Weigh **1,2,3,4** vs **5,6,7,8**
# 2. Depending on outcome, use the second weighing to narrow to 2–3 candidates
# 3. Third weighing identifies the exact coin and whether it is heavy or light
#
# ---
#
# If you want, I can also give this as a **compact table** or the **classic optimal 3-weighing scheme** in a more elegant decision-tree format.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "think and pick a business idea that might be worth exploring for an agentic ai opportunity"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# A strong agentic AI business idea to explore: **AI operations copilot for small/medium B2B service businesses**.
#
# ### What it does
# An AI agent that can **take over routine admin workflows end-to-end** for companies like:
# - accounting firms
# - law firms
# - agencies
# - HR/recruiting shops
# - managed IT providers
# - consultants
#
# Examples of tasks:
# - read incoming emails
# - classify requests
# - gather missing info
# - draft replies
# - update CRM/project tools
# - schedule follow-ups
# - generate invoices or tickets
# - escalate edge cases to humans
#
# ### Why this is a good opportunity
# - These businesses are overloaded with repetitive admin work.
# - They already use email, Slack, calendars, CRMs, ticketing systems, and document tools, which makes integration feasible.
# - The pain is concrete and measurable: time saved, faster response times, fewer dropped leads, fewer missed tasks.
# - Unlike generic “AI assistants,” this can be sold around a specific workflow and ROI.
#
# ### Why it’s “agentic”
# This is not just chat or content generation. The system can:
# - observe incoming events
# - decide what action to take
# - use tools and software
# - follow multi-step workflows
# - ask for approval only when needed
# - learn business-specific rules over time
#
# ### Best wedge to start with
# Pick **one narrow workflow** in one vertical, for example:
# - inbound lead qualification for agencies
# - client intake for law firms
# - invoice follow-up for accounting firms
# - resume screening and interview scheduling for recruiters
#
# A narrow wedge makes it much easier to build reliability and sell ROI.
#
# ### Monetization
# - subscription per business
# - tiered by number of workflows/users/inboxes
# - add-on for custom integrations and onboarding
# - potentially usage-based pricing for actions or handled cases
#
# ### Risks
# - workflow mistakes can be costly, so human approval and audit logs matter
# - integrations are tedious but necessary
# - horizontal “general agent” products are harder to position than vertical workflow products
#
# ### My recommendation
# If I had to pick one:
# **Start with an AI agent for inbound lead and client intake automation for service businesses.**
#
# Why this one:
# - clear economic value
# - easy to understand
# - often begins with email/web forms/chat
# - can expand into scheduling, CRM updates, and follow-ups
# - broad enough to have market size, narrow enough to ship
#
# If you want, I can also give you:
# 1. a **top 10 list of agentic AI business ideas**,
# 2. a **startup idea ranked by ease of execution vs. upside**, or
# 3. a **specific MVP plan** for this idea.

# %%
# First create the messages:

messages = [{"role": "user", "content": f"given the business idea in {business_idea}, what pain points can you identify there? something that might be ripe for an agentic solution. to be sure you recall the idea, give a two sentence summary of the {business_idea} first before you talk about the pain points"}]

# Then make the second call:

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

# Then read the pain point:

pain_point = response.choices[0].message.content
print(pain_point)

# And repeat! In the next message, include the pain point within the message
# Out:
# Yes — I recall it.
#
# **Two-sentence summary:**
# An **AI operations copilot** for small and medium B2B service businesses that automates repetitive admin workflows end-to-end, like handling emails, classifying requests, gathering missing info, updating tools, scheduling follow-ups, and escalating only when needed. The best initial wedge is a **narrow, high-value workflow** in one vertical — especially **inbound lead and client intake automation** — because it’s easy to understand, measurable, and expandable.
#
# Here are the **pain points** that make this ripe for an agentic solution:
#
# ### 1. Inbound requests get lost or delayed
# Businesses often receive leads, client questions, and support requests across email, web forms, Slack, and sometimes phone notes. People miss messages, respond slowly, or fail to route them properly, which means lost revenue and unhappy clients.
#
# ### 2. Staff spend too much time on repetitive admin
# A lot of employee time goes into copying data between inboxes, CRMs, calendars, project tools, and spreadsheets. This work is low-value but constant, and it eats into billable time.
#
# ### 3. Context gathering is manual and annoying
# Many requests arrive incomplete, so someone has to go back and ask for budget, scope, deadlines, documents, or contact details. An agent can do this back-and-forth automatically instead of making a human chase the same info repeatedly.
#
# ### 4. Follow-up discipline is inconsistent
# Leads and tasks often die because no one remembers to follow up at the right time. An agent can monitor pending items, send reminders, and keep the workflow moving without relying on human memory.
#
# ### 5. Too many tools, too little coordination
# These firms already use a stack of email, calendars, CRMs, project managers, ticketing systems, and document tools. The pain is not a lack of software — it’s the lack of a system that connects them and takes action across them.
#
# ### 6. Work is fragmented across people
# Small teams often rely on one or two overloaded people to triage everything. When those people are unavailable, the workflow slows down or breaks. An agent can act as a persistent operational layer that doesn’t forget or get distracted.
#
# ### 7. Response quality is uneven
# Replies may be slow, incomplete, or inconsistent depending on who handles them. An agent can standardize first-response quality, gather the right details, and keep tone and process consistent.
#
# ### 8. Revenue leakage from bad intake
# If lead qualification or client intake is sloppy, firms waste time on poor-fit prospects, miss urgent opportunities, or onboard clients with missing information. Better intake means better conversion and less downstream rework.
#
# ### 9. Human capacity doesn’t scale linearly
# As a firm grows, admin overhead grows too. Hiring more coordinators is expensive, and training them on every nuance takes time. An agent helps scale without immediately adding headcount.
#
# ### 10. Compliance and audit trails are often weak
# In businesses like accounting or law, people need traceability for who said what and when action was taken. A good agent can create logs, capture approvals, and make workflow decisions auditable.
#
# ### Where an agentic solution fits especially well
# The most promising pain point is usually:
#
# **“We get lots of inbound requests, but the process from first contact to properly qualified, scheduled, and logged handoff is messy and manual.”**
#
# That’s ripe for an agent because it requires:
# - observing new events
# - deciding what type of request it is
# - asking for missing details
# - taking action in multiple systems
# - escalating edge cases
# - keeping everything updated and traceable
#
# If you want, I can next turn this into:
# 1. a **problem-solution map**,
# 2. a **specific vertical wedge recommendation**, or
# 3. a **day-in-the-life workflow showing exactly where the agent acts**.

# %%
# First create the messages:

messages = [{"role": "user", "content": f"since we have identified the {business_idea} and the respective {pain_point} in that industry, i need you to think and propose an agentic ai solution to address the {pain_point}. Describe what agents would be involved, how they would collaborate, and what the outcome would be."}]

# Then make the third call:

response = openai.chat.completions.create(
    model="gpt-5.4-mini",
    messages=messages
)

# Then read the solution:

solution = response.choices[0].message.content
print(solution)

from IPython.display import Markdown, display
display(Markdown(solution))

# The final output should have the answer
# Out:
# Absolutely — if we focus on **inbound lead and client intake automation** for a small/medium B2B service business, the most effective design is **not one giant agent**, but a **small team of specialized agents** that collaborate under a shared workflow.
#
# ## Proposed multi-agent system
#
# ### 1. **Intake Monitor Agent**
# **Role:** Watches inbound channels continuously
# **Inputs:** email inboxes, website forms, chat widgets, Slack, voicemail transcriptions
# **Actions:**
# - detects new inquiries
# - deduplicates repeated messages
# - tags the message type: lead, client request, support issue, urgent escalation
# - passes the item to the next agent
#
# **Why it matters:**
# This is the always-on “front door” of the system. It ensures no request gets missed.
#
# ---
#
# ### 2. **Triage / Classification Agent**
# **Role:** Understands what the request is and how important it is
# **Actions:**
# - classifies the request by service line, client type, urgency, and fit
# - checks against business rules
# - decides whether it is:
#   - a qualified lead
#   - an incomplete lead
#   - a current client issue
#   - an out-of-scope request
#   - an escalation
#
# **Why it matters:**
# This agent reduces noise and ensures the business focuses on the right opportunities first.
#
# ---
#
# ### 3. **Information-Gathering Agent**
# **Role:** Fills in missing details
# **Actions:**
# - asks follow-up questions automatically
# - requests missing documents or context
# - gathers budget, timeline, location, company size, needs, or other qualification criteria
# - keeps the conversation moving until enough information is collected
#
# **Why it matters:**
# A lot of intake is blocked because the first message is incomplete. This agent removes that bottleneck.
#
# ---
#
# ### 4. **Scheduling Agent**
# **Role:** Converts qualified opportunities into booked meetings
# **Actions:**
# - offers available time slots
# - coordinates calendars
# - handles rescheduling
# - sends reminders
# - confirms meeting details
#
# **Why it matters:**
# This is where interest turns into revenue. Speed and convenience here matter a lot.
#
# ---
#
# ### 5. **CRM / System Update Agent**
# **Role:** Keeps records synchronized
# **Actions:**
# - creates or updates CRM entries
# - logs conversation history
# - updates pipeline stage
# - creates tasks in project tools
# - attaches documents and metadata
#
# **Why it matters:**
# The agent is only useful if the business’s systems stay current without human rework.
#
# ---
#
# ### 6. **Policy / Approval Agent**
# **Role:** Checks whether the agent can act autonomously or needs human signoff
# **Actions:**
# - verifies compliance rules
# - checks sensitive cases
# - flags edge cases
# - requests approval before sending certain replies or making commitments
#
# **Why it matters:**
# This is critical for law, accounting, recruiting, and other sensitive service businesses.
#
# ---
#
# ### 7. **Escalation Agent**
# **Role:** Hands off tricky cases to the right person
# **Actions:**
# - routes VIP clients, high-value leads, angry customers, or unusual cases to a human
# - summarizes the conversation
# - suggests next actions
# - ensures the human gets a clean handoff
#
# **Why it matters:**
# The system should know when to stop and ask for help.
#
# ---
#
# ### 8. **Follow-up Agent**
# **Role:** Prevents opportunities and tasks from going stale
# **Actions:**
# - monitors pending replies
# - sends reminders
# - nudges prospects who haven’t responded
# - reopens stalled threads
# - escalates aging tasks
#
# **Why it matters:**
# This is where a lot of revenue leakage is prevented.
#
# ---
#
# ## How they collaborate
#
# Think of the workflow like a relay:
#
# 1. **Intake Monitor Agent** sees a new email or form submission.
# 2. It forwards the item to the **Triage Agent**.
# 3. The **Triage Agent** decides whether the request is qualified and what information is missing.
# 4. If needed, the **Information-Gathering Agent** sends a structured follow-up.
# 5. Once qualified, the **Scheduling Agent** books the meeting.
# 6. The **CRM Agent** logs everything and updates internal tools.
# 7. The **Policy Agent** blocks any action that requires approval.
# 8. If the case is unusual, the **Escalation Agent** hands it to a human with a summary.
# 9. The **Follow-up Agent** keeps checking until the case is resolved.
#
# This creates a **persistent operational pipeline** rather than a single chatbot that only reacts when prompted.
#
# ---
#
# ## Example workflow
#
# ### Scenario: A new lead emails an agency
#
# **Incoming message:**
# “Hi, we need help with paid ads for our ecommerce brand. Can you tell us if you work with Shopify stores?”
#
# ### Agent collaboration:
# - **Intake Monitor Agent** captures the email.
# - **Triage Agent** identifies it as a potential lead for the agency.
# - It notices missing info: budget, monthly ad spend, timeline, and decision-maker contact.
# - **Information-Gathering Agent** replies with a friendly intake message asking for those details.
# - The prospect responds.
# - **Triage Agent** determines it is a good-fit lead.
# - **Scheduling Agent** offers meeting times and books a discovery call.
# - **CRM Agent** creates the lead record and logs the thread.
# - **Follow-up Agent** watches for no-shows or unresponsive prospects.
# - If the lead had asked for something outside scope, **Escalation Agent** would notify a human.
#
# ### Outcome:
# - faster response time
# - less manual back-and-forth
# - fewer dropped leads
# - cleaner CRM
# - more booked meetings
# - less admin burden on the team
#
# ---
#
# ## Business outcome
#
# For the business, the outcome is:
#
# - **faster response to inbound requests**
# - **higher conversion from lead to meeting**
# - **less time spent on repetitive admin**
# - **better data quality in CRM and tools**
# - **more consistent client intake**
# - **fewer missed opportunities**
# - **scalable operations without immediate headcount growth**
#
# ---
#
# ## Best way to implement this first
#
# Start with a **single vertical** and a **single workflow**:
# - agencies: inbound lead qualification + scheduling
# - law firms: client intake + conflict-sensitive routing
# - accounting firms: prospect intake + document collection
# - recruiters: candidate screening + interview scheduling
#
# This keeps the agent rules manageable and makes ROI easy to prove.
#
# If you want, I can next turn this into a:
# 1. **system architecture diagram in text**,
# 2. **MVP feature list**, or
# 3. **step-by-step workflow for one specific vertical**.
# Absolutely — if we focus on **inbound lead and client intake automation** for a small/medium B2B service business, the most effective design is **not one giant agent**, but a **small team of specialized agents** that collaborate under a shared workflow.
#
# ## Proposed multi-agent system
#
# ### 1. **Intake Monitor Agent**
# **Role:** Watches inbound channels continuously
# **Inputs:** email inboxes, website forms, chat widgets, Slack, voicemail transcriptions
# **Actions:**
# - detects new inquiries
# - deduplicates repeated messages
# - tags the message type: lead, client request, support issue, urgent escalation
# - passes the item to the next agent
#
# **Why it matters:**
# This is the always-on “front door” of the system. It ensures no request gets missed.
#
# ---
#
# ### 2. **Triage / Classification Agent**
# **Role:** Understands what the request is and how important it is
# **Actions:**
# - classifies the request by service line, client type, urgency, and fit
# - checks against business rules
# - decides whether it is:
#   - a qualified lead
#   - an incomplete lead
#   - a current client issue
#   - an out-of-scope request
#   - an escalation
#
# **Why it matters:**
# This agent reduces noise and ensures the business focuses on the right opportunities first.
#
# ---
#
# ### 3. **Information-Gathering Agent**
# **Role:** Fills in missing details
# **Actions:**
# - asks follow-up questions automatically
# - requests missing documents or context
# - gathers budget, timeline, location, company size, needs, or other qualification criteria
# - keeps the conversation moving until enough information is collected
#
# **Why it matters:**
# A lot of intake is blocked because the first message is incomplete. This agent removes that bottleneck.
#
# ---
#
# ### 4. **Scheduling Agent**
# **Role:** Converts qualified opportunities into booked meetings
# **Actions:**
# - offers available time slots
# - coordinates calendars
# - handles rescheduling
# - sends reminders
# - confirms meeting details
#
# **Why it matters:**
# This is where interest turns into revenue. Speed and convenience here matter a lot.
#
# ---
#
# ### 5. **CRM / System Update Agent**
# **Role:** Keeps records synchronized
# **Actions:**
# - creates or updates CRM entries
# - logs conversation history
# - updates pipeline stage
# - creates tasks in project tools
# - attaches documents and metadata
#
# **Why it matters:**
# The agent is only useful if the business’s systems stay current without human rework.
#
# ---
#
# ### 6. **Policy / Approval Agent**
# **Role:** Checks whether the agent can act autonomously or needs human signoff
# **Actions:**
# - verifies compliance rules
# - checks sensitive cases
# - flags edge cases
# - requests approval before sending certain replies or making commitments
#
# **Why it matters:**
# This is critical for law, accounting, recruiting, and other sensitive service businesses.
#
# ---
#
# ### 7. **Escalation Agent**
# **Role:** Hands off tricky cases to the right person
# **Actions:**
# - routes VIP clients, high-value leads, angry customers, or unusual cases to a human
# - summarizes the conversation
# - suggests next actions
# - ensures the human gets a clean handoff
#
# **Why it matters:**
# The system should know when to stop and ask for help.
#
# ---
#
# ### 8. **Follow-up Agent**
# **Role:** Prevents opportunities and tasks from going stale
# **Actions:**
# - monitors pending replies
# - sends reminders
# - nudges prospects who haven’t responded
# - reopens stalled threads
# - escalates aging tasks
#
# **Why it matters:**
# This is where a lot of revenue leakage is prevented.
#
# ---
#
# ## How they collaborate
#
# Think of the workflow like a relay:
#
# 1. **Intake Monitor Agent** sees a new email or form submission.
# 2. It forwards the item to the **Triage Agent**.
# 3. The **Triage Agent** decides whether the request is qualified and what information is missing.
# 4. If needed, the **Information-Gathering Agent** sends a structured follow-up.
# 5. Once qualified, the **Scheduling Agent** books the meeting.
# 6. The **CRM Agent** logs everything and updates internal tools.
# 7. The **Policy Agent** blocks any action that requires approval.
# 8. If the case is unusual, the **Escalation Agent** hands it to a human with a summary.
# 9. The **Follow-up Agent** keeps checking until the case is resolved.
#
# This creates a **persistent operational pipeline** rather than a single chatbot that only reacts when prompted.
#
# ---
#
# ## Example workflow
#
# ### Scenario: A new lead emails an agency
#
# **Incoming message:**
# “Hi, we need help with paid ads for our ecommerce brand. Can you tell us if you work with Shopify stores?”
#
# ### Agent collaboration:
# - **Intake Monitor Agent** captures the email.
# - **Triage Agent** identifies it as a potential lead for the agency.
# - It notices missing info: budget, monthly ad spend, timeline, and decision-maker contact.
# - **Information-Gathering Agent** replies with a friendly intake message asking for those details.
# - The prospect responds.
# - **Triage Agent** determines it is a good-fit lead.
# - **Scheduling Agent** offers meeting times and books a discovery call.
# - **CRM Agent** creates the lead record and logs the thread.
# - **Follow-up Agent** watches for no-shows or unresponsive prospects.
# - If the lead had asked for something outside scope, **Escalation Agent** would notify a human.
#
# ### Outcome:
# - faster response time
# - less manual back-and-forth
# - fewer dropped leads
# - cleaner CRM
# - more booked meetings
# - less admin burden on the team
#
# ---
#
# ## Business outcome
#
# For the business, the outcome is:
#
# - **faster response to inbound requests**
# - **higher conversion from lead to meeting**
# - **less time spent on repetitive admin**
# - **better data quality in CRM and tools**
# - **more consistent client intake**
# - **fewer missed opportunities**
# - **scalable operations without immediate headcount growth**
#
# ---
#
# ## Best way to implement this first
#
# Start with a **single vertical** and a **single workflow**:
# - agencies: inbound lead qualification + scheduling
# - law firms: client intake + conflict-sensitive routing
# - accounting firms: prospect intake + document collection
# - recruiters: candidate screening + interview scheduling
#
# This keeps the agent rules manageable and makes ROI easy to prove.
#
# If you want, I can next turn this into a:
# 1. **system architecture diagram in text**,
# 2. **MVP feature list**, or
# 3. **step-by-step workflow for one specific vertical**.
