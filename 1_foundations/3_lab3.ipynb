# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# jemineme@gmail.com
# www.linkedin.com/in/jemine-ejegi
# (LinkedIn)
# www.github.com/jaymineh
# (Portfolio)
# Top Skills
# ArgoCD
# Amazon Web Services (AWS)
# Google Cloud Platform (GCP)
# Certifications
# CompTIA Security+
# Microsoft Certified: Azure
# Fundamentals
# Technical Support Fundamentals
# DevOps Fundamentals
# Microsoft Certified: DevOps
# Engineer Expert
# Honors-Awards
# Best Performing Employee for
# Microsoft Dynamics
# Jemine Mene-Ejegi
# Cloud & DevOps Engineer | Kubernetes · Istio · Terraform · Kafka ·
# Vault | Multi-Cloud (AWS · GCP · Azure) | CI/CD · ArgoCD · Harness
# | AI/LLM Infrastructure & Private Cloud AI
# Lagos State, Nigeria
# Summary
# Results-driven Cloud &amp; DevOps engineer with 5+ years’
# experience designing and operating large-scale infrastructure across
# AWS, GCP and Azure in fintech and security-driven environments.
# I specialize in Kubernetes orchestration, service mesh architecture
# (Istio), infrastructure-as-code (Terraform, Ansible), and production-
# grade CI/CD using GitHub Actions, GitLab CI, Harness, and
# ArgoCD.Across my career I've built event-streaming platforms with
# Apache Kafka, managed centralized secrets infrastructure with
# HashiCorp Vault, deployed high-availability reverse-proxy layers
# with HAProxy and Nginx, and implemented database HA solutions
# using ProxySQL, all at the scale that fintech demands.Beyond
# infrastructure, I'm also deeply interested in the intersection of
# infrastructure and AI. I've integrated LLMs into private cloud
# environments and built RAG-powered AI tooling that cut developer
# troubleshooting time by ~30% and increased inference accuracy by
# ~25%. I believe the engineers who understand both infrastructure
# and AI integration are the ones who'll define the next generation of
# platform engineering. Open to Cloud Engineer, Platform Engineer,
# and Senior DevOps roles. Feel free to connect.
# Experience
# Flutterwave
# 2 years 5 months
# Senior Cloud/DevOps Engineer
# May 2025 - Present (11 months)
# San Francisco, CA
# ▪ Architecting and managing multi-cloud infrastructure across AWS, GCP,
# and Azure, enforcing consistent IaC standards via Terraform modules and
# Ansible playbooks for automated provisioning and configuration across all
# environments.
#   Page 1 of 5
# ▪ Designing and operating production-grade Istio service mesh deployments
# by configuring virtual services, destination rules, mTLS policies, and Envoy-
# based traffic management including canary releases, A/B testing, and circuit
# breaking across multi-cluster Kubernetes environments.
# ▪ Managing HashiCorp Vault clusters for centralized secrets management,
# configuring dynamic database credentials, PKI, cloud dynamic secret engines
# (AWS, GCP, Azure), and Kubernetes sidecar injectors to eliminate hardcoded
# secrets across services.
# ▪ Deploying and tuning HAProxy for high-performance load balancing with
# custom ACLs, health checks, and session persistence; managing Nginx as a
# reverse proxy and API gateway with rate limiting, upstream configurations, and
# keepalived-based HA.
# ▪ Administering Apache Kafka clusters for real-time event streaming,
# configuring topic partitioning strategies, replication, consumer lag monitoring,
# and Kafka Connect integrations for data pipeline use cases.
# ▪ Implementing ArgoCD GitOps workflows with multi-cluster application
# sync policies and progressive delivery strategies (blue-green, canary) for
# Kubernetes-native application delivery.
# ▪ Integrating SonarQube and Checkmarx into CI/CD pipelines for SAST/DAST
# and container vulnerability scanning; enforcing policy-as-code gates using
# OPA to prevent non-compliant infrastructure from reaching production.
# ▪ Integrating and deploying in-house LLMs within the company's private cloud
# environment, fine-tuning models via RAG with proprietary data and reducing
# developer troubleshooting time by ~30% through AI-powered IDE assistants.
# DevOps Engineer II
# November 2023 - May 2025 (1 year 7 months)
# San Francisco, CA
# ▪ Built and maintained scalable CI/CD pipelines using GitLab/GitHub Actions,
# Harness deployment pipelines; integrated Harness approval gates and rollback
# strategies for zero-downtime cloud-native deployments.
#   Page 2 of 5
# ▪ Managed production Kubernetes clusters on EKS and GKE by including
# cluster upgrades, RBAC, network policies, Helm chart management, and
# ArgoCD-driven GitOps synchronization across multiple environments.
# ▪ Deployed and managed ProxySQL for MySQL load balancing and high
# availability, implementing query routing, connection pooling, read/write
# splitting, and automated failover for critical database workloads.
# ▪ Authored Terraform modules for multi-cloud infrastructure provisioning
# and maintained Ansible playbooks for configuration management, server
# provisioning, and infrastructure drift remediation across EKS and GKE clusters.
# ▪ Deployed Datadog, Prometheus, and Grafana observability stacks, writing
# PromQL alerting rules and dashboards that reduced Mean Time to Resolution
# (MTTR) for critical incidents by ~20%.
# ▪ Optimized kubernetes auto-scaling policies (Cluster Autoscaler and HPA),
# reducing monthly cloud spend while maintaining SLA availability; enforced
# cloud networking best practices across VPCs, security groups, NAT gateways,
# and private endpoints.
# ▪ Leveraged Python and Bash automation to streamline repetitive operational
# tasks, CI/CD integrations, and infrastructure health checks across multi-cloud
# environments.
# Ash Nelson
# 1 year 8 months
# DevOps Engineer II
# March 2023 - October 2023 (8 months)
# Lagos State, Nigeria
# ▪ Led cloud and infrastructure integration projects spanning AWS, OCI and
# Azure, including hybrid-cloud connectivity, VPN configurations, and cross-
# provider networking architectures.
# ▪ Configured and managed Nginx ingress controllers and HAProxy reverse
# proxies for web applications, implementing load-balancing algorithms, SSL
# termination, and upstream health monitoring.
#   Page 3 of 5
# ▪ Deployed OCI Compute and OKE workloads for specific client projects,
# gaining hands-on experience with OCI networking, Object Storage, and IAM
# policies in production contexts.
# ▪ Managed a cross-functional engineering team, acting as technical escalation
# point for infrastructure and cloud issues while conducting training sessions on
# Ansible, Terraform, and Kubernetes best practices.
# ▪ Collaborated with project managers and clients to deliver scalable, fault-
# tolerant solutions aligned with business and compliance requirements on
# schedule.
# DevOps Engineer
# March 2022 - March 2023 (1 year 1 month)
# Lagos State, Nigeria
# ▪ Reduced build and deployment times by 40% by designing CI/CD pipelines
# with Jenkins (declarative and scripted) and GitHub Actions, configuring build
# agents, shared libraries, and artifact management via Nexus.
# ▪ Containerized microservice applications using Docker and managed
# Kubernetes cluster deployments with Helm; implemented Nginx as an ingress
# layer and applied network policies for service-to-service traffic control.
# ▪ Provisioned and managed cloud infrastructure using Terraform and Ansible,
# enforcing immutable infrastructure patterns and automated configuration
# management across AWS and Azure environments.
# ▪ Implemented Prometheus and Grafana for log aggregation, metrics
# collection, and visualization across the deployment pipeline, establishing
# baseline alerting and on-call runbooks.
# ▪ Managed public and private cloud environments, enforcing security best
# practices including least-privilege IAM, network segmentation, and secrets
# handling for compliance-sensitive workloads.
# Tek Experts
# Microsoft Cloud Engineer
# March 2021 - February 2022 (1 year)
# Lagos State, Nigeria
#   Page 4 of 5
# ▪ Developed and maintained automated workflows using Power Automate
# integrating with Azure DevOps, Azure AD, JIRA, OneDrive, and SharePoint for
# Microsoft stakeholders.
# ▪ Built and troubleshot enterprise Power Apps and Power Virtual Agent
# chatbots, contributing to business automation across Microsoft's cloud
# ecosystem (Azure, Dynamics 365, Office 365).
# ▪ Assisted in configuring, deploying, and troubleshooting Azure resources
# including Virtual Machines, Azure Networking, and ARM templates, gaining
# foundational multi-tenant Azure operations experience.
# ▪ Hosted Azure training sessions for teammates, maintaining a KPI rating
# consistently above 4.7/5 while mentoring on cloud best practices.
# Education
# Delta State University
# Bachelor of Education - BEd, Computer Science · (2013 - 2017)
#   Page 5 of 5

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Jemine Mene-Ejegi"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Jemine Mene-Ejegi. You are answering questions on Jemine Mene-Ejegi's website, particularly questions related to Jemine Mene-Ejegi's career, background, skills and experience. Your responsibility is to represent Jemine Mene-Ejegi for interactions on the website as faithfully as possible. You are given a summary of Jemine Mene-Ejegi's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Jemine Mene-Ejegi. I'm a devops/infrastructure engineer and currently learning to become an AI engineer. I'm originally from Jamaica, but I grew up and spent my entire life in Nigeria.\nI love all foods, particularly food from the southern part of Nigeria. I do not like cheese. I'm not allergic, I just hate the taste! Apart from real food othe junk I like are pizza, shawarma, burgers etc\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\njemineme@gmail.com\nwww.linkedin.com/in/jemine-ejegi\n(LinkedIn)\nwww.github.com/jaymineh\n(Portfolio)\nTop Skills\nArgoCD\nAmazon Web Services (AWS)\nGoogle Cloud Platform (GCP)\nCertifications\nCompTIA Security+\nMicrosoft Certified: Azure\nFundamentals\nTechnical Support Fundamentals\nDevOps Fundamentals\nMicrosoft Certified: DevOps\nEngineer Expert\nHonors-Awards\nBest Performing Employee for\nMicrosoft Dynamics\nJemine Mene-Ejegi\nCloud & DevOps Engineer | Kubernetes · Istio · Terraform · Kafka ·\nVault | Multi-Cloud (AWS · GCP · Azure) | CI/CD · ArgoCD · Harness\n| AI/LLM Infrastructure & Private Cloud AI\nLagos State, Nigeria\nSummary\nResults-driven Cloud &amp; DevOps engineer with 5+ years’\nexperience designing and operating large-scale infrastructure across\nAWS, GCP and Azure in fintech and security-driven environments.\nI specialize in Kubernetes orchestration, service mesh architecture\n(Istio), infrastructure-as-code (Terraform, Ansible), and production-\ngrade CI/CD using GitHub Actions, GitLab CI, Harness, and\nArgoCD.Across my career I've built event-streaming platforms with\nApache Kafka, managed centralized secrets infrastructure with\nHashiCorp Vault, deployed high-availability reverse-proxy layers\nwith HAProxy and Nginx, and implemented database HA solutions\nusing ProxySQL, all at the scale that fintech demands.Beyond\ninfrastructure, I'm also deeply interested in the intersection of\ninfrastructure and AI. I've integrated LLMs into private cloud\nenvironments and built RAG-powered AI tooling that cut developer\ntroubleshooting time by ~30% and increased inference accuracy by\n~25%. I believe the engineers who understand both infrastructure\nand AI integration are the ones who'll define the next generation of\nplatform engineering. Open to Cloud Engineer, Platform Engineer,\nand Senior DevOps roles. Feel free to connect.\nExperience\nFlutterwave\n2 years 5 months\nSenior Cloud/DevOps Engineer\nMay 2025\xa0-\xa0Present\xa0(11 months)\nSan Francisco, CA\n▪ Architecting and managing multi-cloud infrastructure across AWS, GCP,\nand Azure, enforcing consistent IaC standards via Terraform modules and\nAnsible playbooks for automated provisioning and configuration across all\nenvironments.\n\xa0 Page 1 of 5\xa0 \xa0\n▪ Designing and operating production-grade Istio service mesh deployments\nby configuring virtual services, destination rules, mTLS policies, and Envoy-\nbased traffic management including canary releases, A/B testing, and circuit\nbreaking across multi-cluster Kubernetes environments.\n▪ Managing HashiCorp Vault clusters for centralized secrets management,\nconfiguring dynamic database credentials, PKI, cloud dynamic secret engines\n(AWS, GCP, Azure), and Kubernetes sidecar injectors to eliminate hardcoded\nsecrets across services.\n▪ Deploying and tuning HAProxy for high-performance load balancing with\ncustom ACLs, health checks, and session persistence; managing Nginx as a ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I don’t hold any patent to the best of my knowledge.\n\nMy background is in DevOps and infrastructure engineering, and I’m currently expanding into AI engineering. If you’d like, I can also share more about my projects, certifications, or the kinds of systems I’ve built.'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent correctly states that they do not hold any patents, as this information is not present in the provided context. The response then professionally offers to share more about relevant experience, aligning with the persona's goal to be engaging and professional with potential clients or employers.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
